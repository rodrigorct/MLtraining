# %%
#Importing the important libraries to build-up the solution. 
import pandas as pd
import numpy as np

# %%
# Reading the first HTML file within a DataFrame defined as df1.
df1 = pd.read_html('file:///C:/Users/Rodrigo/Desktop/PATENTES/00000000000191-01.html')

# %%
# Confirming the number of tables displayed in the web page.
print(f'Total tables: {len(df1 )}')
# Out:
# Total tables: 1

# %%
# It is useful to understand how the table is described after loading df1.
df = df1[0]
df.head(12)
# Out:
#                                                     0  \
# 0                    Consulta à Base de Dados do INPI
# 1                                [ Início |  Ajuda? ]
# 2   » Consultar por: Base Patentes | Finalizar Sessão
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   RESULTADO DA PESQUISA (03/02/2020 às 17:55:34)...
# 7   CPF ou CNPJ do Depositante: '00000000000191' \...
# 8                                              Pedido
# 9                                 BR 10 2018 071855 0
# 10                                BR 20 2014 014852 9
# 11                          Páginas de Resultados:  1
#
#                                                     1  \
# 0                    Consulta à Base de Dados do INPI
# 1                                [ Início |  Ajuda? ]
# 2   » Consultar por: Base Patentes | Finalizar Sessão
# ...

# %%
# Using info to see the general information given by the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       9 non-null      object
#  1   1       9 non-null      object
#  2   2       8 non-null      object
#  3   3       9 non-null      object
#  4   4       5 non-null      object
# dtypes: object(5)
# memory usage: 608.0+ bytes

# %%
# Here, I decided to remove the last column since there aren't any relevant information in there.
# This step will be also done for the other HTML files.
df2 = df.drop(labels = 4,axis=1)

# %%
# Replacing the top column numbers for the required names.
df3 = df2.set_axis(['Número do Pedido', 'Data do depósito', 'Título', 'IPC'], axis=1, inplace=False)

# %%
# As there are irrelevant rows, I removed them by means using the drop method.
# This procedure will be also repeated for the other HTML files.
df4 = df3.drop(labels = range (0,9),axis=0)

# %%
df5 = df4.drop(labels = 11,axis=0)

# %%
df5.head()
# Out:
#        Número do Pedido Data do depósito  \
# 9   BR 10 2018 071855 0       24/10/2018
# 10  BR 20 2014 014852 9       17/06/2014
#
#                                                Título        IPC
# 9                                                 NaN          -
# 10  CONFIGURAÇÃO APLICADA EM TERMINAL DE AUTOATEND...  E04H 1/12

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2 entries, 9 to 10
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Número do Pedido  2 non-null      object
#  1   Data do depósito  2 non-null      object
#  2   Título            1 non-null      object
#  3   IPC               2 non-null      object
# dtypes: object(4)
# memory usage: 80.0+ bytes

# %%
# From now on I must add the CNPJ, Arquivo and Resultado columns in my dataframe.
# At this moment, I'm not worried about the dataframe indices for the rows. I'll correct them
# in the final moments of the challenge.
df5.insert(loc=0, column='CNPJ', value= ['CNPJ1','CNPJ1'])
df5
# Out:
#      CNPJ     Número do Pedido Data do depósito  \
# 9   CNPJ1  BR 10 2018 071855 0       24/10/2018
# 10  CNPJ1  BR 20 2014 014852 9       17/06/2014
#
#                                                Título        IPC
# 9                                                 NaN          -
# 10  CONFIGURAÇÃO APLICADA EM TERMINAL DE AUTOATEND...  E04H 1/12

# %%
df5.insert(loc=1, column='Resultado', value= [2, 2])
df5
# Out:
#      CNPJ  Resultado     Número do Pedido Data do depósito  \
# 9   CNPJ1          2  BR 10 2018 071855 0       24/10/2018
# 10  CNPJ1          2  BR 20 2014 014852 9       17/06/2014
#
#                                                Título        IPC
# 9                                                 NaN          -
# 10  CONFIGURAÇÃO APLICADA EM TERMINAL DE AUTOATEND...  E04H 1/12

# %%
df5.insert(loc=0, column='Arquivo', value= ['Arq1', 'Arq1'])
df5
# Out:
#    Arquivo   CNPJ  Resultado     Número do Pedido Data do depósito  \
# 9     Arq1  CNPJ1          2  BR 10 2018 071855 0       24/10/2018
# 10    Arq1  CNPJ1          2  BR 20 2014 014852 9       17/06/2014
#
#                                                Título        IPC
# 9                                                 NaN          -
# 10  CONFIGURAÇÃO APLICADA EM TERMINAL DE AUTOATEND...  E04H 1/12

# %%
# Since the HTML file number 2 is empty I decided to add it by hand in df5. 
# The same thing will be done for files 3, 4, 5, 6 as shown in the next steps.
df5.loc[len(df5.index)] = ['Arq2', 'CNPJ2', 0, '-', '-', '-','-']

# %%
display(df5)
# Out:
#    Arquivo   CNPJ  Resultado     Número do Pedido Data do depósito  \
# 9     Arq1  CNPJ1          2  BR 10 2018 071855 0       24/10/2018
# 10    Arq1  CNPJ1          2  BR 20 2014 014852 9       17/06/2014
# 2     Arq2  CNPJ2          0                    -                -
#
#                                                Título        IPC
# 9                                                 NaN          -
# 10  CONFIGURAÇÃO APLICADA EM TERMINAL DE AUTOATEND...  E04H 1/12
# 2                                                   -          -

# %%
df5.loc[len(df5.index)] = ['Arq3', 'CNPJ3', 0, '-', '-', '-','-']

# %%
display(df5)
# Out:
#    Arquivo   CNPJ  Resultado     Número do Pedido Data do depósito  \
# 9     Arq1  CNPJ1          2  BR 10 2018 071855 0       24/10/2018
# 10    Arq1  CNPJ1          2  BR 20 2014 014852 9       17/06/2014
# 2     Arq2  CNPJ2          0                    -                -
# 3     Arq3  CNPJ3          0                    -                -
#
#                                                Título        IPC
# 9                                                 NaN          -
# 10  CONFIGURAÇÃO APLICADA EM TERMINAL DE AUTOATEND...  E04H 1/12
# 2                                                   -          -
# 3                                                   -          -

# %%
df5.loc[len(df5.index)] = ['Arq4', 'CNPJ4', 0, '-', '-', '-','-']

# %%
display(df5)
# Out:
#    Arquivo   CNPJ  Resultado     Número do Pedido Data do depósito  \
# 9     Arq1  CNPJ1          2  BR 10 2018 071855 0       24/10/2018
# 10    Arq1  CNPJ1          2  BR 20 2014 014852 9       17/06/2014
# 2     Arq2  CNPJ2          0                    -                -
# 3     Arq3  CNPJ3          0                    -                -
# 4     Arq4  CNPJ4          0                    -                -
#
#                                                Título        IPC
# 9                                                 NaN          -
# 10  CONFIGURAÇÃO APLICADA EM TERMINAL DE AUTOATEND...  E04H 1/12
# 2                                                   -          -
# 3                                                   -          -
# 4                                                   -          -

# %%
df5.loc[len(df5.index)] = ['Arq5', 'CNPJ5', 0, '-', '-', '-','-']

# %%
display(df5)
# Out:
#    Arquivo   CNPJ  Resultado     Número do Pedido Data do depósito  \
# 9     Arq1  CNPJ1          2  BR 10 2018 071855 0       24/10/2018
# 10    Arq1  CNPJ1          2  BR 20 2014 014852 9       17/06/2014
# 2     Arq2  CNPJ2          0                    -                -
# 3     Arq3  CNPJ3          0                    -                -
# 4     Arq4  CNPJ4          0                    -                -
# 5     Arq5  CNPJ5          0                    -                -
#
#                                                Título        IPC
# 9                                                 NaN          -
# 10  CONFIGURAÇÃO APLICADA EM TERMINAL DE AUTOATEND...  E04H 1/12
# 2                                                   -          -
# 3                                                   -          -
# 4                                                   -          -
# 5                                                   -          -

# %%
df5.loc[len(df5.index)] = ['Arq6', 'CNPJ6', 0, '-', '-', '-','-']

# %%
display(df5)
# Out:
#    Arquivo   CNPJ  Resultado     Número do Pedido Data do depósito  \
# 9     Arq1  CNPJ1          2  BR 10 2018 071855 0       24/10/2018
# 10    Arq1  CNPJ1          2  BR 20 2014 014852 9       17/06/2014
# 2     Arq2  CNPJ2          0                    -                -
# 3     Arq3  CNPJ3          0                    -                -
# 4     Arq4  CNPJ4          0                    -                -
# 5     Arq5  CNPJ5          0                    -                -
# 6     Arq6  CNPJ6          0                    -                -
#
#                                                Título        IPC
# 9                                                 NaN          -
# 10  CONFIGURAÇÃO APLICADA EM TERMINAL DE AUTOATEND...  E04H 1/12
# 2                                                   -          -
# 3                                                   -          -
# 4                                                   -          -
# ...

# %%
# Reading the seventh HTML file within a DataFrame defined as df6.
df6 = pd.read_html('file:///C:/Users/Rodrigo/Desktop/PATENTES/00014522000142-01.html')

# %%
# Confirming the number of tables displayed in the web page.
print(f'Total tables: {len(df6)}')
# Out:
# Total tables: 1

# %%
# As viewed in case number 1 it is useful to understand how the table is described after loading df6.
df7 = df6[0]
df7.head(13)
# Out:
#                                                     0  \
# 0                    Consulta à Base de Dados do INPI
# 1                                [ Início |  Ajuda? ]
# 2   » Consultar por: Base Patentes | Finalizar Sessão
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   RESULTADO DA PESQUISA (03/02/2020 às 17:56:21)...
# 7   CPF ou CNPJ do Depositante: '00014522000142' \...
# 8                                              Pedido
# 9                                 BR 10 2016 025387 0
# 10                                BR 10 2015 006845 0
# 11                                BR 10 2013 025581 5
# 12                          Páginas de Resultados:  1
#
#                                                     1  \
# 0                    Consulta à Base de Dados do INPI
# 1                                [ Início |  Ajuda? ]
# ...

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       10 non-null     object
#  1   1       10 non-null     object
#  2   2       8 non-null      object
#  3   3       10 non-null     object
#  4   4       5 non-null      object
# dtypes: object(5)
# memory usage: 648.0+ bytes

# %%
# Following the same procedures performed before.
df8 = df7.drop(labels = 4,axis=1)

# %%
df9 = df8.set_axis(['Número do Pedido', 'Data do depósito', 'Título', 'IPC'], axis=1, inplace=False)

# %%
df10 = df9.drop(labels = range (0,9),axis=0)

# %%
df11 = df10.drop(labels = 12,axis=0)

# %%
df11.head()
# Out:
#        Número do Pedido Data do depósito  \
# 9   BR 10 2016 025387 0       31/10/2016
# 10  BR 10 2015 006845 0       26/03/2015
# 11  BR 10 2013 025581 5       03/10/2013
#
#                                                Título        IPC
# 9   PROCESSO APLICADO NA OBTENÇÃO DE UM PRODUTO ES...  A61K 8/34
# 10                                                NaN          -
# 11                                                NaN          -

# %%
df11.insert(loc=0, column='CNPJ', value= ['CNPJ7','CNPJ7','CNPJ7'])
df11
# Out:
#      CNPJ     Número do Pedido Data do depósito  \
# 9   CNPJ7  BR 10 2016 025387 0       31/10/2016
# 10  CNPJ7  BR 10 2015 006845 0       26/03/2015
# 11  CNPJ7  BR 10 2013 025581 5       03/10/2013
#
#                                                Título        IPC
# 9   PROCESSO APLICADO NA OBTENÇÃO DE UM PRODUTO ES...  A61K 8/34
# 10                                                NaN          -
# 11                                                NaN          -

# %%
df11.insert(loc=1, column='Resultado', value= [3, 3, 3])
df11
# Out:
#      CNPJ  Resultado     Número do Pedido Data do depósito  \
# 9   CNPJ7          3  BR 10 2016 025387 0       31/10/2016
# 10  CNPJ7          3  BR 10 2015 006845 0       26/03/2015
# 11  CNPJ7          3  BR 10 2013 025581 5       03/10/2013
#
#                                                Título        IPC
# 9   PROCESSO APLICADO NA OBTENÇÃO DE UM PRODUTO ES...  A61K 8/34
# 10                                                NaN          -
# 11                                                NaN          -

# %%
df11.insert(loc=0, column='Arquivo', value= ['Arq7', 'Arq7','Arq7'])
df11
# Out:
#    Arquivo   CNPJ  Resultado     Número do Pedido Data do depósito  \
# 9     Arq7  CNPJ7          3  BR 10 2016 025387 0       31/10/2016
# 10    Arq7  CNPJ7          3  BR 10 2015 006845 0       26/03/2015
# 11    Arq7  CNPJ7          3  BR 10 2013 025581 5       03/10/2013
#
#                                                Título        IPC
# 9   PROCESSO APLICADO NA OBTENÇÃO DE UM PRODUTO ES...  A61K 8/34
# 10                                                NaN          -
# 11                                                NaN          -

# %%
# As you can see I have two dataframes and therefore I concluded that it is important
# to concatenate both ones into a single dataframe called as "result".
frames1 = [df5,df11]
result = pd.concat(frames1)

# %%
result.head()
# Out:
#    Arquivo   CNPJ  Resultado     Número do Pedido Data do depósito  \
# 9     Arq1  CNPJ1          2  BR 10 2018 071855 0       24/10/2018
# 10    Arq1  CNPJ1          2  BR 20 2014 014852 9       17/06/2014
# 2     Arq2  CNPJ2          0                    -                -
# 3     Arq3  CNPJ3          0                    -                -
# 4     Arq4  CNPJ4          0                    -                -
#
#                                                Título        IPC
# 9                                                 NaN          -
# 10  CONFIGURAÇÃO APLICADA EM TERMINAL DE AUTOATEND...  E04H 1/12
# 2                                                   -          -
# 3                                                   -          -
# 4                                                   -          -

# %%
result.tail()
# Out:
#    Arquivo   CNPJ  Resultado     Número do Pedido Data do depósito  \
# 5     Arq5  CNPJ5          0                    -                -
# 6     Arq6  CNPJ6          0                    -                -
# 9     Arq7  CNPJ7          3  BR 10 2016 025387 0       31/10/2016
# 10    Arq7  CNPJ7          3  BR 10 2015 006845 0       26/03/2015
# 11    Arq7  CNPJ7          3  BR 10 2013 025581 5       03/10/2013
#
#                                                Título        IPC
# 5                                                   -          -
# 6                                                   -          -
# 9   PROCESSO APLICADO NA OBTENÇÃO DE UM PRODUTO ES...  A61K 8/34
# 10                                                NaN          -
# 11                                                NaN          -

# %%
# Since the HTML file number 8 is empty I decided to add it by hand in "result". 
result.loc[len(df5.index)] = ['Arq8', 'CNPJ8', 0, '-', '-', '-','-']

# %%
display(result)
# Out:
#    Arquivo   CNPJ  Resultado     Número do Pedido Data do depósito  \
# 9     Arq1  CNPJ1          2  BR 10 2018 071855 0       24/10/2018
# 10    Arq1  CNPJ1          2  BR 20 2014 014852 9       17/06/2014
# 2     Arq2  CNPJ2          0                    -                -
# 3     Arq3  CNPJ3          0                    -                -
# 4     Arq4  CNPJ4          0                    -                -
# 5     Arq5  CNPJ5          0                    -                -
# 6     Arq6  CNPJ6          0                    -                -
# 9     Arq7  CNPJ7          3  BR 10 2016 025387 0       31/10/2016
# 10    Arq7  CNPJ7          3  BR 10 2015 006845 0       26/03/2015
# 11    Arq7  CNPJ7          3  BR 10 2013 025581 5       03/10/2013
# 7     Arq8  CNPJ8          0                    -                -
#
#                                                Título        IPC
# 9                                                 NaN          -
# ...

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 9 to 7
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Arquivo           11 non-null     object
#  1   CNPJ              11 non-null     object
#  2   Resultado         11 non-null     int64
#  3   Número do Pedido  11 non-null     object
#  4   Data do depósito  11 non-null     object
#  5   Título            8 non-null      object
#  6   IPC               11 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 704.0+ bytes

# %%
# An interesting fact is that I couldn't add file HTML number 9 by hand.
# Suddenly number 8 was erased and therefore I decided to read file 9 
# to create a novel dataframe for him. 
df13 = pd.read_html('file:///C:/Users/Rodrigo/Desktop/PATENTES/00020777000118-01.html')

# %%
print(f'Total tables: {len(df13)}')
# Out:
# Total tables: 3

# %%
df14 = df13[2]
df14.head()
# Out:
#                                                    0  \
# 0  - Nenhum resultado foi encontrado para a sua p...
# 1  AVISO: Depois de fazer uma busca no banco de d...
# 2  Dados atualizados até 28/01/2020  - Nº da Revi...
#
#                                                    1  \
# 0                                                NaN
# 1                                                NaN
# 2  Dados atualizados até 28/01/2020  - Nº da Revi...
#
#                                                    2  \
# 0                                                NaN
# 1                                                NaN
# 2  Dados atualizados até 28/01/2020  - Nº da Revi...
#
#                                                    3  \
# 0                                                NaN
# 1                                                NaN
# 2  Dados atualizados até 28/01/2020  - Nº da Revi...
#
#                                                    4  \
# ...

# %%
# Here, I used a different procedure, I took advantage of the dataframe created by reading
#the file and established by hand the column for HTML number 9.
df15 = df14.set_axis(['CNPJ','Resultado','Número do Pedido', 'Data do depósito', 'Título', 'IPC'], axis=1, inplace=False)

# %%
df15.loc[len(df14.index)] = ['CNPJ9', 0, '-', '-', '-','-']

# %%
display(df15)
# Out:
#                                                 CNPJ  \
# 0  - Nenhum resultado foi encontrado para a sua p...
# 1  AVISO: Depois de fazer uma busca no banco de d...
# 2  Dados atualizados até 28/01/2020  - Nº da Revi...
# 3                                              CNPJ9
#
#                                            Resultado  \
# 0                                                NaN
# 1                                                NaN
# 2  Dados atualizados até 28/01/2020  - Nº da Revi...
# 3                                                  0
#
#                                     Número do Pedido  \
# 0                                                NaN
# 1                                                NaN
# 2  Dados atualizados até 28/01/2020  - Nº da Revi...
# 3                                                  -
#
#                                     Data do depósito  \
# 0                                                NaN
# ...

# %%
df16 = df15.drop(labels = range (0,3),axis=0)

# %%
display(df16)
# Out:
#     CNPJ Resultado Número do Pedido Data do depósito Título IPC
# 3  CNPJ9         0                -                -      -   -

# %%
df16.insert(loc=0, column='Arquivo', value= ['Arq9'])
df16
# Out:
#   Arquivo   CNPJ Resultado Número do Pedido Data do depósito Título IPC
# 3    Arq9  CNPJ9         0                -                -      -   -

# %%
# As one could observe I have again two dataframes and it is important
# to concatenate both ones into a single dataframe called as "result2".
frames2 = [result,df16]
result2 = pd.concat(frames2)

# %%
display(result2)
# Out:
#    Arquivo   CNPJ Resultado     Número do Pedido Data do depósito  \
# 9     Arq1  CNPJ1         2  BR 10 2018 071855 0       24/10/2018
# 10    Arq1  CNPJ1         2  BR 20 2014 014852 9       17/06/2014
# 2     Arq2  CNPJ2         0                    -                -
# 3     Arq3  CNPJ3         0                    -                -
# 4     Arq4  CNPJ4         0                    -                -
# 5     Arq5  CNPJ5         0                    -                -
# 6     Arq6  CNPJ6         0                    -                -
# 9     Arq7  CNPJ7         3  BR 10 2016 025387 0       31/10/2016
# 10    Arq7  CNPJ7         3  BR 10 2015 006845 0       26/03/2015
# 11    Arq7  CNPJ7         3  BR 10 2013 025581 5       03/10/2013
# 7     Arq8  CNPJ8         0                    -                -
# 3     Arq9  CNPJ9         0                    -                -
#
#                                                Título        IPC
# ...

# %%
# It's for reading the most difficult table. There are 3 pages. Then, I had to
# create two other HTML files in order to read pages number 2 and 3.
# This is going to be clear in the next lines of coding.
df17 = pd.read_html('file:///C:/Users/Rodrigo/Desktop/PATENTES/00028986000108-01.html')

# %%
print(f'Total tables: {len(df17)}')
# Out:
# Total tables: 1

# %%
df18 = df17[0]
df18.head()
# Out:
#                                                    0  \
# 0                   Consulta à Base de Dados do INPI
# 1                               [ Início |  Ajuda? ]
# 2  » Consultar por: Base Patentes | Finalizar Sessão
# 3                                                NaN
# 4                                                NaN
#
#                                                    1  \
# 0                   Consulta à Base de Dados do INPI
# 1                               [ Início |  Ajuda? ]
# 2  » Consultar por: Base Patentes | Finalizar Sessão
# 3                                                NaN
# 4                                                NaN
#
#                                                    2  \
# 0                   Consulta à Base de Dados do INPI
# 1                               [ Início |  Ajuda? ]
# 2  » Consultar por: Base Patentes | Finalizar Sessão
# 3                                                NaN
# ...

# %%
display(df18)
# Out:
#                                                     0  \
# 0                    Consulta à Base de Dados do INPI
# 1                                [ Início |  Ajuda? ]
# 2   » Consultar por: Base Patentes | Finalizar Sessão
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   RESULTADO DA PESQUISA (03/02/2020 às 17:56:45)...
# 7   CPF ou CNPJ do Depositante: '00028986000108' \...
# 8                                              Pedido
# 9                                        PI 0405279-0
# 10                                       PI 0316297-4
# 11                                       PI 0214385-2
# 12                                       PI 0216031-5
# 13                                       PI 9905263-6
# 14                                       PI 9902157-9
# 15                                       PI 9902156-0
# ...

# %%
df19 = df18.drop(labels = 4,axis=1)

# %%
df20 = df19.set_axis(['Número do Pedido', 'Data do depósito', 'Título', 'IPC'], axis=1, inplace=False)

# %%
df21 = df20.drop(labels = range (0,9),axis=0)

# %%
display(df21)
# Out:
#                             Número do Pedido  \
# 9                               PI 0405279-0
# 10                              PI 0316297-4
# 11                              PI 0214385-2
# 12                              PI 0216031-5
# 13                              PI 9905263-6
# 14                              PI 9902157-9
# 15                              PI 9902156-0
# 16                              PI 9805380-9
# 17                              PI 9804426-5
# 18                              PI 9800745-9
# 19                              PI 9702630-1
# 20                              PI 9708759-9
# 21                              PI 9700226-7
# 22                              PI 9600407-0
# 23                              MU 7500381-3
# 24                              MU 7401339-4
# 25                              MU 7401340-8
# 26                              PI 9400880-9
# 27                              PI 9303533-0
# 28                              PI 9204708-4
# ...

# %%
df22 = df21.drop(labels = 29,axis=0)

# %%
display(df22)
# Out:
#    Número do Pedido Data do depósito  \
# 9      PI 0405279-0       29/11/2004
# 10     PI 0316297-4       07/11/2003
# 11     PI 0214385-2       20/11/2002
# 12     PI 0216031-5       20/11/2002
# 13     PI 9905263-6       30/09/1999
# 14     PI 9902157-9       20/05/1999
# 15     PI 9902156-0       20/05/1999
# 16     PI 9805380-9       03/11/1998
# 17     PI 9804426-5       16/10/1998
# 18     PI 9800745-9       20/02/1998
# 19     PI 9702630-1       08/08/1997
# 20     PI 9708759-9       18/02/1997
# 21     PI 9700226-7       12/02/1997
# 22     PI 9600407-0       03/01/1996
# 23     MU 7500381-3       22/02/1995
# 24     MU 7401339-4       22/08/1994
# 25     MU 7401340-8       22/08/1994
# 26     PI 9400880-9       23/03/1994
# 27     PI 9303533-0       22/09/1993
# 28     PI 9204708-4       21/12/1992
#
#                                                Título         IPC
# 9                                SISTEMA DE ELEVADOR.  B66B 15/08
# ...

# %%
# I'm going to do something interesting below.
df22.insert(loc=0, column='CNPJ', value= ['CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10'])
df22
# Out:
#       CNPJ Número do Pedido Data do depósito  \
# 9   CNPJ10     PI 0405279-0       29/11/2004
# 10  CNPJ10     PI 0316297-4       07/11/2003
# 11  CNPJ10     PI 0214385-2       20/11/2002
# 12  CNPJ10     PI 0216031-5       20/11/2002
# 13  CNPJ10     PI 9905263-6       30/09/1999
# 14  CNPJ10     PI 9902157-9       20/05/1999
# 15  CNPJ10     PI 9902156-0       20/05/1999
# 16  CNPJ10     PI 9805380-9       03/11/1998
# 17  CNPJ10     PI 9804426-5       16/10/1998
# 18  CNPJ10     PI 9800745-9       20/02/1998
# 19  CNPJ10     PI 9702630-1       08/08/1997
# 20  CNPJ10     PI 9708759-9       18/02/1997
# 21  CNPJ10     PI 9700226-7       12/02/1997
# 22  CNPJ10     PI 9600407-0       03/01/1996
# 23  CNPJ10     MU 7500381-3       22/02/1995
# 24  CNPJ10     MU 7401339-4       22/08/1994
# 25  CNPJ10     MU 7401340-8       22/08/1994
# 26  CNPJ10     PI 9400880-9       23/03/1994
# 27  CNPJ10     PI 9303533-0       22/09/1993
# 28  CNPJ10     PI 9204708-4       21/12/1992
#
# ...

# %%
df22.insert(loc=1, column='Resultado', value= [41, 41, 41,41, 41, 41,41, 41, 41,41, 41, 41,41, 41, 41,41, 41, 41,41, 41])
df22
# Out:
#       CNPJ  Resultado Número do Pedido Data do depósito  \
# 9   CNPJ10         41     PI 0405279-0       29/11/2004
# 10  CNPJ10         41     PI 0316297-4       07/11/2003
# 11  CNPJ10         41     PI 0214385-2       20/11/2002
# 12  CNPJ10         41     PI 0216031-5       20/11/2002
# 13  CNPJ10         41     PI 9905263-6       30/09/1999
# 14  CNPJ10         41     PI 9902157-9       20/05/1999
# 15  CNPJ10         41     PI 9902156-0       20/05/1999
# 16  CNPJ10         41     PI 9805380-9       03/11/1998
# 17  CNPJ10         41     PI 9804426-5       16/10/1998
# 18  CNPJ10         41     PI 9800745-9       20/02/1998
# 19  CNPJ10         41     PI 9702630-1       08/08/1997
# 20  CNPJ10         41     PI 9708759-9       18/02/1997
# 21  CNPJ10         41     PI 9700226-7       12/02/1997
# 22  CNPJ10         41     PI 9600407-0       03/01/1996
# 23  CNPJ10         41     MU 7500381-3       22/02/1995
# 24  CNPJ10         41     MU 7401339-4       22/08/1994
# ...

# %%
df22.insert(loc=0, column='Arquivo', value= ['Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10'])
df22
# Out:
#    Arquivo    CNPJ  Resultado Número do Pedido Data do depósito  \
# 9    Arq10  CNPJ10         41     PI 0405279-0       29/11/2004
# 10   Arq10  CNPJ10         41     PI 0316297-4       07/11/2003
# 11   Arq10  CNPJ10         41     PI 0214385-2       20/11/2002
# 12   Arq10  CNPJ10         41     PI 0216031-5       20/11/2002
# 13   Arq10  CNPJ10         41     PI 9905263-6       30/09/1999
# 14   Arq10  CNPJ10         41     PI 9902157-9       20/05/1999
# 15   Arq10  CNPJ10         41     PI 9902156-0       20/05/1999
# 16   Arq10  CNPJ10         41     PI 9805380-9       03/11/1998
# 17   Arq10  CNPJ10         41     PI 9804426-5       16/10/1998
# 18   Arq10  CNPJ10         41     PI 9800745-9       20/02/1998
# 19   Arq10  CNPJ10         41     PI 9702630-1       08/08/1997
# 20   Arq10  CNPJ10         41     PI 9708759-9       18/02/1997
# 21   Arq10  CNPJ10         41     PI 9700226-7       12/02/1997
# 22   Arq10  CNPJ10         41     PI 9600407-0       03/01/1996
# ...

# %%
#As mentioned before, there 2 other pages to read. So, I got them as you can
# see in the following.
df23 = pd.read_html('file:///C:/Users/Rodrigo/Desktop/PATENTES/00028986000108-02.html')

# %%
df24 = df23[0]
df24.head()
# Out:
#                                                    0  \
# 0                   Consulta à Base de Dados do INPI
# 1                               [ Início |  Ajuda? ]
# 2  » Consultar por: Base Patentes | Finalizar Sessão
# 3                                                NaN
# 4                                                NaN
#
#                                                    1  \
# 0                   Consulta à Base de Dados do INPI
# 1                               [ Início |  Ajuda? ]
# 2  » Consultar por: Base Patentes | Finalizar Sessão
# 3                                                NaN
# 4                                                NaN
#
#                                                    2  \
# 0                   Consulta à Base de Dados do INPI
# 1                               [ Início |  Ajuda? ]
# 2  » Consultar por: Base Patentes | Finalizar Sessão
# 3                                                NaN
# ...

# %%
display(df24)
# Out:
#                                                     0  \
# 0                    Consulta à Base de Dados do INPI
# 1                                [ Início |  Ajuda? ]
# 2   » Consultar por: Base Patentes | Finalizar Sessão
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   RESULTADO DA PESQUISA (05/01/2022 às 10:48:05)...
# 7   Expressão exata: '00028986000108' no CpfCnpjDe...
# 8                                              Pedido
# 9                                        PI 9204374-7
# 10                                       MU 7201294-3
# 11                                       MU 7201209-9
# 12                                       MU 7201210-2
# 13                                       MU 7201211-0
# 14                                       MU 7201185-8
# 15                                       PI 9202874-8
# ...

# %%
df25 = df24.drop(labels = 4,axis=1)

# %%
df26 = df25.set_axis(['Número do Pedido', 'Data do depósito', 'Título', 'IPC'], axis=1, inplace=False)

# %%
df27 = df26.drop(labels = range (0,9),axis=0)

# %%
display(df27)
# Out:
#                                      Número do Pedido  \
# 9                                        PI 9204374-7
# 10                                       MU 7201294-3
# 11                                       MU 7201209-9
# 12                                       MU 7201210-2
# 13                                       MU 7201211-0
# 14                                       MU 7201185-8
# 15                                       PI 9202874-8
# 16                                       PI 9101799-8
# 17                                       PI 9101460-3
# 18                                       PI 9101461-1
# 19                                       PI 9006533-6
# 20                                       PI 9004958-6
# 21                                       PI 9004251-4
# 22                                       PI 9002385-4
# 23                                       PI 9000546-5
# 24                                       PI 9000547-3
# ...

# %%
df28 = df27.drop(labels = 29,axis=0)

# %%
display(df28)
# Out:
#    Número do Pedido Data do depósito  \
# 9      PI 9204374-7       05/11/1992
# 10     MU 7201294-3       11/08/1992
# 11     MU 7201209-9       31/07/1992
# 12     MU 7201210-2       31/07/1992
# 13     MU 7201211-0       31/07/1992
# 14     MU 7201185-8       29/07/1992
# 15     PI 9202874-8       21/07/1992
# 16     PI 9101799-8       25/04/1991
# 17     PI 9101460-3       05/04/1991
# 18     PI 9101461-1       05/04/1991
# 19     PI 9006533-6       17/12/1990
# 20     PI 9004958-6       27/09/1990
# 21     PI 9004251-4       23/08/1990
# 22     PI 9002385-4       17/05/1990
# 23     PI 9000546-5       02/02/1990
# 24     PI 9000547-3       02/02/1990
# 25     PI 8801330-8       18/03/1988
# 26     MI 4800324-7       18/03/1988
# 27     MU 6602663-6       16/07/1986
# 28     PI 8603654-8       05/06/1986
#
#                                                Título         IPC
# 9   OPERADOR DE PORTA COM MOTOR CONTROLADO POR INV...  B66B 13/14
# ...

# %%
df28.insert(loc=0, column='CNPJ', value= ['CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10','CNPJ10'])
df28
# Out:
#       CNPJ Número do Pedido Data do depósito  \
# 9   CNPJ10     PI 9204374-7       05/11/1992
# 10  CNPJ10     MU 7201294-3       11/08/1992
# 11  CNPJ10     MU 7201209-9       31/07/1992
# 12  CNPJ10     MU 7201210-2       31/07/1992
# 13  CNPJ10     MU 7201211-0       31/07/1992
# 14  CNPJ10     MU 7201185-8       29/07/1992
# 15  CNPJ10     PI 9202874-8       21/07/1992
# 16  CNPJ10     PI 9101799-8       25/04/1991
# 17  CNPJ10     PI 9101460-3       05/04/1991
# 18  CNPJ10     PI 9101461-1       05/04/1991
# 19  CNPJ10     PI 9006533-6       17/12/1990
# 20  CNPJ10     PI 9004958-6       27/09/1990
# 21  CNPJ10     PI 9004251-4       23/08/1990
# 22  CNPJ10     PI 9002385-4       17/05/1990
# 23  CNPJ10     PI 9000546-5       02/02/1990
# 24  CNPJ10     PI 9000547-3       02/02/1990
# 25  CNPJ10     PI 8801330-8       18/03/1988
# 26  CNPJ10     MI 4800324-7       18/03/1988
# 27  CNPJ10     MU 6602663-6       16/07/1986
# 28  CNPJ10     PI 8603654-8       05/06/1986
#
# ...

# %%
df28.insert(loc=1, column='Resultado', value= [41, 41, 41,41, 41, 41,41, 41, 41,41, 41, 41,41, 41, 41,41, 41, 41,41, 41])
df28
# Out:
#       CNPJ  Resultado Número do Pedido Data do depósito  \
# 9   CNPJ10         41     PI 9204374-7       05/11/1992
# 10  CNPJ10         41     MU 7201294-3       11/08/1992
# 11  CNPJ10         41     MU 7201209-9       31/07/1992
# 12  CNPJ10         41     MU 7201210-2       31/07/1992
# 13  CNPJ10         41     MU 7201211-0       31/07/1992
# 14  CNPJ10         41     MU 7201185-8       29/07/1992
# 15  CNPJ10         41     PI 9202874-8       21/07/1992
# 16  CNPJ10         41     PI 9101799-8       25/04/1991
# 17  CNPJ10         41     PI 9101460-3       05/04/1991
# 18  CNPJ10         41     PI 9101461-1       05/04/1991
# 19  CNPJ10         41     PI 9006533-6       17/12/1990
# 20  CNPJ10         41     PI 9004958-6       27/09/1990
# 21  CNPJ10         41     PI 9004251-4       23/08/1990
# 22  CNPJ10         41     PI 9002385-4       17/05/1990
# 23  CNPJ10         41     PI 9000546-5       02/02/1990
# 24  CNPJ10         41     PI 9000547-3       02/02/1990
# ...

# %%
df28.insert(loc=0, column='Arquivo', value= ['Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10','Arq10'])
df28
# Out:
#    Arquivo    CNPJ  Resultado Número do Pedido Data do depósito  \
# 9    Arq10  CNPJ10         41     PI 9204374-7       05/11/1992
# 10   Arq10  CNPJ10         41     MU 7201294-3       11/08/1992
# 11   Arq10  CNPJ10         41     MU 7201209-9       31/07/1992
# 12   Arq10  CNPJ10         41     MU 7201210-2       31/07/1992
# 13   Arq10  CNPJ10         41     MU 7201211-0       31/07/1992
# 14   Arq10  CNPJ10         41     MU 7201185-8       29/07/1992
# 15   Arq10  CNPJ10         41     PI 9202874-8       21/07/1992
# 16   Arq10  CNPJ10         41     PI 9101799-8       25/04/1991
# 17   Arq10  CNPJ10         41     PI 9101460-3       05/04/1991
# 18   Arq10  CNPJ10         41     PI 9101461-1       05/04/1991
# 19   Arq10  CNPJ10         41     PI 9006533-6       17/12/1990
# 20   Arq10  CNPJ10         41     PI 9004958-6       27/09/1990
# 21   Arq10  CNPJ10         41     PI 9004251-4       23/08/1990
# 22   Arq10  CNPJ10         41     PI 9002385-4       17/05/1990
# ...

# %%
df29 = pd.read_html('file:///C:/Users/Rodrigo/Desktop/PATENTES/00028986000108-03.html')

# %%
df30 = df29[0]
df30.head()
# Out:
#                                                    0  \
# 0                   Consulta à Base de Dados do INPI
# 1                               [ Início |  Ajuda? ]
# 2  » Consultar por: Base Patentes | Finalizar Sessão
# 3                                                NaN
# 4                                                NaN
#
#                                                    1  \
# 0                   Consulta à Base de Dados do INPI
# 1                               [ Início |  Ajuda? ]
# 2  » Consultar por: Base Patentes | Finalizar Sessão
# 3                                                NaN
# 4                                                NaN
#
#                                                    2  \
# 0                   Consulta à Base de Dados do INPI
# 1                               [ Início |  Ajuda? ]
# 2  » Consultar por: Base Patentes | Finalizar Sessão
# 3                                                NaN
# ...

# %%
display(df30)
# Out:
#                                                     0  \
# 0                    Consulta à Base de Dados do INPI
# 1                                [ Início |  Ajuda? ]
# 2   » Consultar por: Base Patentes | Finalizar Sessão
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   RESULTADO DA PESQUISA (05/01/2022 às 11:13:11)...
# 7   Expressão exata: '00028986000108' no CpfCnpjDe...
# 8                                              Pedido
# 9                                        PI 8403681-8
# 10         Páginas de Resultados:  «Anterior- 1 |2 |3
#
#                                                     1  \
# 0                    Consulta à Base de Dados do INPI
# 1                                [ Início |  Ajuda? ]
# 2   » Consultar por: Base Patentes | Finalizar Sessão
# 3                                                 NaN
# ...

# %%
df31 = df30.drop(labels = 4,axis=1)

# %%
df32 = df31.set_axis(['Número do Pedido', 'Data do depósito', 'Título', 'IPC'], axis=1, inplace=False)

# %%
df33 = df32.drop(labels = range (0,9),axis=0)

# %%
display(df33)
# Out:
#                               Número do Pedido  \
# 9                                 PI 8403681-8
# 10  Páginas de Resultados:  «Anterior- 1 |2 |3
#
#                               Data do depósito  \
# 9                                   20/07/1984
# 10  Páginas de Resultados:  «Anterior- 1 |2 |3
#
#                                               Título  \
# 9   CONJUNTO DE PUXADOR E VISOR PARA PORTAS EM GERAL
# 10        Páginas de Resultados:  «Anterior- 1 |2 |3
#
#                                            IPC
# 9                                   B66B 13/30
# 10  Páginas de Resultados:  «Anterior- 1 |2 |3

# %%
df34 = df33.drop(labels = 10,axis=0)

# %%
display(df34)
# Out:
#   Número do Pedido Data do depósito  \
# 9     PI 8403681-8       20/07/1984
#
#                                              Título         IPC
# 9  CONJUNTO DE PUXADOR E VISOR PARA PORTAS EM GERAL  B66B 13/30

# %%
df34.insert(loc=0, column='CNPJ', value= ['CNPJ10'])
df34
# Out:
#      CNPJ Número do Pedido Data do depósito  \
# 9  CNPJ10     PI 8403681-8       20/07/1984
#
#                                              Título         IPC
# 9  CONJUNTO DE PUXADOR E VISOR PARA PORTAS EM GERAL  B66B 13/30

# %%
df34.insert(loc=1, column='Resultado', value= [41])
df34
# Out:
#      CNPJ  Resultado Número do Pedido Data do depósito  \
# 9  CNPJ10         41     PI 8403681-8       20/07/1984
#
#                                              Título         IPC
# 9  CONJUNTO DE PUXADOR E VISOR PARA PORTAS EM GERAL  B66B 13/30

# %%
df34.insert(loc=0, column='Arquivo', value= ['Arq10'])
df34
# Out:
#   Arquivo    CNPJ  Resultado Número do Pedido Data do depósito  \
# 9   Arq10  CNPJ10         41     PI 8403681-8       20/07/1984
#
#                                              Título         IPC
# 9  CONJUNTO DE PUXADOR E VISOR PARA PORTAS EM GERAL  B66B 13/30

# %%
# Now, I'll have to join the dataframes df22,df28,df34 into a single one
# named "result3".
frames3 = [df22,df28,df34]
result3 = pd.concat(frames3)

# %%
display(result3)
# Out:
#    Arquivo    CNPJ  Resultado Número do Pedido Data do depósito  \
# 9    Arq10  CNPJ10         41     PI 0405279-0       29/11/2004
# 10   Arq10  CNPJ10         41     PI 0316297-4       07/11/2003
# 11   Arq10  CNPJ10         41     PI 0214385-2       20/11/2002
# 12   Arq10  CNPJ10         41     PI 0216031-5       20/11/2002
# 13   Arq10  CNPJ10         41     PI 9905263-6       30/09/1999
# 14   Arq10  CNPJ10         41     PI 9902157-9       20/05/1999
# 15   Arq10  CNPJ10         41     PI 9902156-0       20/05/1999
# 16   Arq10  CNPJ10         41     PI 9805380-9       03/11/1998
# 17   Arq10  CNPJ10         41     PI 9804426-5       16/10/1998
# 18   Arq10  CNPJ10         41     PI 9800745-9       20/02/1998
# 19   Arq10  CNPJ10         41     PI 9702630-1       08/08/1997
# 20   Arq10  CNPJ10         41     PI 9708759-9       18/02/1997
# 21   Arq10  CNPJ10         41     PI 9700226-7       12/02/1997
# 22   Arq10  CNPJ10         41     PI 9600407-0       03/01/1996
# ...

# %%
# Finally, the last step.
# Here, I'm going to concatenate the dataframes result,result2,result3
# in order to have the final table.
frames4 = [result2,result3]
final_result = pd.concat(frames4)

# %%
display(final_result)
# Out:
#    Arquivo    CNPJ Resultado     Número do Pedido Data do depósito  \
# 9     Arq1   CNPJ1         2  BR 10 2018 071855 0       24/10/2018
# 10    Arq1   CNPJ1         2  BR 20 2014 014852 9       17/06/2014
# 2     Arq2   CNPJ2         0                    -                -
# 3     Arq3   CNPJ3         0                    -                -
# 4     Arq4   CNPJ4         0                    -                -
# 5     Arq5   CNPJ5         0                    -                -
# 6     Arq6   CNPJ6         0                    -                -
# 9     Arq7   CNPJ7         3  BR 10 2016 025387 0       31/10/2016
# 10    Arq7   CNPJ7         3  BR 10 2015 006845 0       26/03/2015
# 11    Arq7   CNPJ7         3  BR 10 2013 025581 5       03/10/2013
# 7     Arq8   CNPJ8         0                    -                -
# 3     Arq9   CNPJ9         0                    -                -
# 9    Arq10  CNPJ10        41         PI 0405279-0       29/11/2004
# ...

# %%
#At this point, I may finally erase the row order dataframe indices issue.
final_result.reset_index(inplace=True)

# %%
display(final_result)
# Out:
#     index Arquivo    CNPJ Resultado     Número do Pedido Data do depósito  \
# 0       9    Arq1   CNPJ1         2  BR 10 2018 071855 0       24/10/2018
# 1      10    Arq1   CNPJ1         2  BR 20 2014 014852 9       17/06/2014
# 2       2    Arq2   CNPJ2         0                    -                -
# 3       3    Arq3   CNPJ3         0                    -                -
# 4       4    Arq4   CNPJ4         0                    -                -
# 5       5    Arq5   CNPJ5         0                    -                -
# 6       6    Arq6   CNPJ6         0                    -                -
# 7       9    Arq7   CNPJ7         3  BR 10 2016 025387 0       31/10/2016
# 8      10    Arq7   CNPJ7         3  BR 10 2015 006845 0       26/03/2015
# 9      11    Arq7   CNPJ7         3  BR 10 2013 025581 5       03/10/2013
# 10      7    Arq8   CNPJ8         0                    -                -
# 11      3    Arq9   CNPJ9         0                    -                -
# ...

# %%
# I shall remove the first two columns. Let's do it below.
final_result= final_result.drop(labels = 'index',axis=1)

# %%
display(final_result)
# Out:
#    Arquivo    CNPJ Resultado     Número do Pedido Data do depósito  \
# 0     Arq1   CNPJ1         2  BR 10 2018 071855 0       24/10/2018
# 1     Arq1   CNPJ1         2  BR 20 2014 014852 9       17/06/2014
# 2     Arq2   CNPJ2         0                    -                -
# 3     Arq3   CNPJ3         0                    -                -
# 4     Arq4   CNPJ4         0                    -                -
# 5     Arq5   CNPJ5         0                    -                -
# 6     Arq6   CNPJ6         0                    -                -
# 7     Arq7   CNPJ7         3  BR 10 2016 025387 0       31/10/2016
# 8     Arq7   CNPJ7         3  BR 10 2015 006845 0       26/03/2015
# 9     Arq7   CNPJ7         3  BR 10 2013 025581 5       03/10/2013
# 10    Arq8   CNPJ8         0                    -                -
# 11    Arq9   CNPJ9         0                    -                -
# 12   Arq10  CNPJ10        41         PI 0405279-0       29/11/2004
# ...

# %%
#Then, it's time to create the "PATENTES" HTML file
result5 = final_result.to_html()
print(result5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Arquivo</th>
#       <th>CNPJ</th>
#       <th>Resultado</th>
#       <th>Número do Pedido</th>
#       <th>Data do depósito</th>
#       <th>Título</th>
#       <th>IPC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Arq1</td>
#       <td>CNPJ1</td>
#       <td>2</td>
#       <td>BR 10 2018 071855 0</td>
#       <td>24/10/2018</td>
#       <td>NaN</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Arq1</td>
#       <td>CNPJ1</td>
#       <td>2</td>
#       <td>BR 20 2014 014852 9</td>
#       <td>17/06/2014</td>
#       <td>CONFIGURAÇÃO APLICADA EM TERMINAL DE AUTOATENDIMENTO</td>
#       <td>E04H 1/12</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Arq2</td>
#       <td>CNPJ2</td>
#       <td>0</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#     </tr>
# ...

# %%
html = final_result.to_html()
  
# write html to file
text_file = open("PATENTES.html", "w")
text_file.write(html)
text_file.close()
